# %% [markdown]
# <div style="font-family: 'Segoe UI', Roboto, Arial, sans-serif; background: linear-gradient(135deg,#e8f0fe 0%,#f3f7fb 100%); padding: 24px; border-radius: 16px; color:#1a2b3c;">
#
# <h1 style="color:#0b2b4a; border-bottom: 4px solid #2a7de1; padding-bottom: 8px; display:flex; align-items:center; gap:10px;">
# Ejercicio 2: Escalamiento de tickets de soporte técnico
# </h1>
#
# <h2 style="color:#1e4a76; margin-top:24px;">Ficha PEAS</h2>
#
# <table style="width:100%; border-collapse: collapse; border-radius:12px; overflow:hidden; box-shadow: 0 4px 12px rgba(0,20,50,0.08);">
#   <thead>
#     <tr style="background: linear-gradient(135deg,#1a3e64,#235a8f); color:white;">
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Componente</th>
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Descripción</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Percepción (S)</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">tiempo_espera_minutos</code> (int),
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">nivel_urgencia</code>
#         (<span style="background:#d9f2e6; color:#0e7a4a; padding:2px 8px; border-radius:6px; font-size:0.85em;">baja</span> /
#          <span style="background:#fef3d6; color:#92600a; padding:2px 8px; border-radius:6px; font-size:0.85em;">media</span> /
#          <span style="background:#fde8e8; color:#b13e3e; padding:2px 8px; border-radius:6px; font-size:0.85em;">alta</span>),
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">cliente_premium</code>
#         (<span style="background:#d9f2e6; color:#0e7a4a; padding:2px 8px; border-radius:6px; font-size:0.85em;">true</span> /
#          <span style="background:#fde8e8; color:#b13e3e; padding:2px 8px; border-radius:6px; font-size:0.85em;">false</span>).
#       </td>
#     </tr>
#     <tr>
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Acciones (A)</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">
#         <span style="background:#d4f5e3; color:#0b6b3e; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #9de0bd;">atención estándar nivel 1</span>
#         <span style="background:#fef3d6; color:#92600a; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #f5d98a;">escalar a nivel 2</span>
#         <span style="background:#fde0e0; color:#a12b2b; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #f5b3b3;">escalar a nivel 3</span>
#       </td>
#     </tr>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Entorno (E)</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Sistema de soporte al cliente, cola de tickets y equipo técnico de atención.</td>
#     </tr>
#     <tr>
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Objetivo</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Resolver incidencias garantizando el cumplimiento de SLA y maximizar el nivel de satisfacción del cliente.</td>
#     </tr>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a;">Medida de desempeño (P)</td>
#       <td style="padding:12px 16px;">Tiempo medio de resolución, tasa de cumplimiento de SLA y puntuación CSAT.</td>
#     </tr>
#   </tbody>
# </table>
#
# <h2 style="color:#1e4a76; margin-top:28px;">Justificación de las reglas</h2>
#
# <div style="background:#f0f7ff; border-left:6px solid #2a7de1; padding:18px 22px; border-radius:0 12px 12px 0; box-shadow: 0 2px 8px rgba(42,125,225,0.08);">
#   <p style="margin:0 0 10px 0; color:#1a3b5c;">
#     Priorizar de forma inmediata las incidencias de <b>urgencia alta</b> o procedentes de
#     <b>clientes VIP</b> con tiempos de espera acumulados previene el incumplimiento grave
#     de acuerdos SLA.
#   </p>
#   <p style="margin:0; color:#1a3b5c;">
#     Para incidencias moderadas o clientes regulares con tiempos de espera prolongados, se
#     redirige la atención al <b>nivel 2</b> para descongestionar el nivel primario sin saturar
#     a los especialistas de nivel 3.
#   </p>
# </div>
#
# </div>
