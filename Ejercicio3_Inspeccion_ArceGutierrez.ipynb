# %% [markdown]
# <div style="font-family: 'Segoe UI', Roboto, Arial, sans-serif; background: linear-gradient(135deg,#e8f0fe 0%,#f3f7fb 100%); padding: 24px; border-radius: 16px; color:#1a2b3c;">
#
# <h1 style="color:#0b2b4a; border-bottom: 4px solid #2a7de1; padding-bottom: 8px; display:flex; align-items:center; gap:10px;">
# Ejercicio 3: Inspección visual de un producto
# </h1>
#
# <h2 style="color:#1e4a76; margin-top:24px;">Ficha PEAS</h2>
#
# <table style="width:100%; border-collapse: collapse; border-radius:12px; overflow:hidden; box-shadow: 0 4px 12px rgba(0,20,50,0.08);">
#   <thead>
#     <tr style="background: linear-gradient(135deg,#1a3e64,#235a8f); color:white;">
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Componente</th>
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Descripción</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Percepción (S)</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">
#         Matriz NumPy <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">5x5</code>
#         con valores binarios
#         (<span style="background:#d9f2e6; color:#0e7a4a; padding:2px 8px; border-radius:6px; font-size:0.85em;">0 = píxel normal</span> /
#          <span style="background:#fde8e8; color:#b13e3e; padding:2px 8px; border-radius:6px; font-size:0.85em;">1 = píxel defectuoso</span>).
#       </td>
#     </tr>
#     <tr>
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Acciones (A)</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">
#         <span style="background:#d4f5e3; color:#0b6b3e; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #9de0bd;">aprobar</span>
#         <span style="background:#fef3d6; color:#92600a; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #f5d98a;">revisión manual</span>
#         <span style="background:#fde0e0; color:#a12b2b; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #f5b3b3;">rechazar</span>
#       </td>
#     </tr>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Entorno (E)</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Cinta transportadora de producción industrial y sensor de cámara óptica.</td>
#     </tr>
#     <tr>
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Objetivo</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Asegurar la calidad del producto reduciendo la tasa de defectos de salida al mínimo.</td>
#     </tr>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a;">Medida de desempeño (P)</td>
#       <td style="padding:12px 16px;">Porcentaje de productos defectuosos no detectados, costo de reproceso e índice de unidades rechazadas.</td>
#     </tr>
#   </tbody>
# </table>
#
# <h2 style="color:#1e4a76; margin-top:28px;">Justificación de las reglas</h2>
#
# <div style="background:#f0f7ff; border-left:6px solid #2a7de1; padding:18px 22px; border-radius:0 12px 12px 0; box-shadow: 0 2px 8px rgba(42,125,225,0.08);">
#   <p style="margin:0 0 10px 0; color:#1a3b5c;">
#     Se requiere <b>perfección absoluta</b> (0 defectos) para el despacho directo automatizado
#     de productos. Un recuento de <b>1 a 3 píxeles defectuosos</b> se deriva a revisión manual
#     para evaluar si el fallo es corregible o cosmético, reduciendo el desperdicio.
#   </p>
#   <p style="margin:0; color:#1a3b5c;">
#     Si el producto supera los <b>3 píxeles defectuosos</b>, se descarta directamente por ser
#     irrecuperable y evitar pérdidas de tiempo de reproceso.
#   </p>
# </div>
#
# </div>

# %% [markdown]
# <div style="font-family: 'Segoe UI', Roboto, Arial, sans-serif; background: linear-gradient(135deg,#e8f0fe 0%,#f3f7fb 100%); padding: 20px 24px; border-radius: 16px; color:#1a2b3c;">
#
# <h2 style="color:#1e4a76; margin:0; font-weight:600;">
# Implementación del código
# </h2>
#
# </div>

# %%
import numpy as np

def agente_inspeccion(imagen):
    """
    Percepción (S): matriz 5x5 de NumPy (0 = normal, 1 = defectuoso)
    """
    defectos = int(np.sum(imagen == 1))
    
    if defectos == 0:
        return "aprobar", f"Producto libre de imprecisiones ({defectos} defectos detectados)."
    elif defectos <= 3:
        return "revisión manual", f"Defectos menores detectados ({defectos} defectos). Requiere inspección visual."
    else:
        return "rechazar", f"Producto fuera de tolerancia ({defectos} defectos detectados)."

# %% [markdown]
# <div style="font-family: 'Segoe UI', Roboto, Arial, sans-serif; background: linear-gradient(135deg,#e8f0fe 0%,#f3f7fb 100%); padding: 20px 24px; border-radius: 16px; color:#1a2b3c;">
#
# <h2 style="color:#1e4a76; margin:0; font-weight:600;">
# Simulacion y pruebas
# </h2>
#
# </div>

# %%
import matplotlib.pyplot as plt

# Matrices 
img_0_defectos = np.zeros((5, 5), dtype=int)

img_1_defecto = np.zeros((5, 5), dtype=int)
img_1_defecto[2, 2] = 1

img_3_defectos = np.zeros((5, 5), dtype=int) # Caso límite
img_3_defectos[0, 1] = 1
img_3_defectos[2, 3] = 1
img_3_defectos[4, 0] = 1

img_5_defectos = np.zeros((5, 5), dtype=int)
img_5_defectos[0, 0] = 1
img_5_defectos[1, 1] = 1
img_5_defectos[2, 2] = 1
img_5_defectos[3, 3] = 1
img_5_defectos[4, 4] = 1

imagenes_prueba = [
    ("Matriz Sin Defectos", img_0_defectos),
    ("Matriz 1 Defecto", img_1_defecto),
    ("Matriz 3 Defectos (Borde)", img_3_defectos),
    ("Matriz 5 Defectos", img_5_defectos)
]

print("--- PRUEBAS DE INSPECCIÓN VISUAL ---")
for nombre, img in imagenes_prueba:
    accion, motivo = agente_inspeccion(img)
    print(f"{nombre} => {accion.upper()}: {motivo}")

# Visualización gráfica de las matrices
fig, axes = plt.subplots(1, 4, figsize=(12, 3))
for ax, (nombre, img) in zip(axes, imagenes_prueba):
    ax.imshow(img, cmap='gray_r')
    ax.set_title(nombre, fontsize=9)
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# --- PRUEBAS DE INSPECCIÓN VISUAL ---
# Matriz Sin Defectos => APROBAR: Producto libre de imprecisiones (0 defectos detectados).
# Matriz 1 Defecto => REVISIÓN MANUAL: Defectos menores detectados (1 defectos). Requiere inspección visual.
# Matriz 3 Defectos (Borde) => REVISIÓN MANUAL: Defectos menores detectados (3 defectos). Requiere inspección visual.
# Matriz 5 Defectos => RECHAZAR: Producto fuera de tolerancia (5 defectos detectados).
